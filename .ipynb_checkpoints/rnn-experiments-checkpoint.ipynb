# %%
import json
import pprint
import collections
import requests
import pandas as pd
import numpy as np
import gensim

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn import preprocessing
from matplotlib import pyplot as plt

import logging
logging.basicConfig(format='%(levelname)s : %(message)s', level=logging.INFO)
logging.root.level = logging.INFO  # ipython sometimes messes up the logging setup; restore

# %%
all_data = pd.read_csv('data/sequence-data/1000-trial-1.csv', index_col=0)

# %%
all_blocks = []
for col in all_data:
    blocks = all_data[col].unique()
    all_blocks.extend(blocks)
block_vocab = list(set(all_blocks))

# %%
all_block_docs = all_data.values.tolist()

# %%
block_vocab[:5]
# Out:
# ['motion_turnright',
#  'data_deleteoflist',
#  'control_create_clone_of',
#  'sound_setvolumeto',
#  'looks_hide']

# %% [markdown]
# # RNN

# %%
from numpy import array
from numpy import cumsum
import tensorflow as tf

# %% [markdown]
# # Word2Vec trial

# %%
# Global hyper parameters
hp = {
    "size": 150, # size of the one-hot-encoded word vectors
    "window": 3, # context size
    "min_count": 2,
    "workers": 4,
    "iter": 10
}

# %%
model = gensim.models.Word2Vec(
        all_block_docs,
        size=hp["size"],
        window=hp["window"],
        min_count=hp["min_count"],
        workers=hp["workers"])
# Out:
# WARNING : consider setting layer size to a multiple of 4 for greater performance
# INFO : collecting all words and their counts
# INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO : PROGRESS: at sentence #10000, processed 50000 words, keeping 73 word types
# INFO : PROGRESS: at sentence #20000, processed 100000 words, keeping 78 word types
# INFO : PROGRESS: at sentence #30000, processed 150000 words, keeping 82 word types
# INFO : PROGRESS: at sentence #40000, processed 200000 words, keeping 85 word types
# INFO : PROGRESS: at sentence #50000, processed 250000 words, keeping 88 word types
# INFO : PROGRESS: at sentence #60000, processed 300000 words, keeping 89 word types
# INFO : PROGRESS: at sentence #70000, processed 350000 words, keeping 90 word types
# INFO : PROGRESS: at sentence #80000, processed 400000 words, keeping 93 word types
# INFO : PROGRESS: at sentence #90000, processed 450000 words, keeping 94 word types
# INFO : PROGRESS: at sentence #100000, processed 500000 words, keeping 94 word types
# INFO : PROGRESS: at sentence #110000, processed 550000 words, keeping 96 word types
# INFO : PROGRESS: at sentence #120000, processed 600000 words, keeping 96 word types
# INFO : PROGRESS: at sentence #130000, processed 650000 words, keeping 99 word types
# INFO : PROGRESS: at sentence #140000, processed 700000 words, keeping 99 word types
# INFO : PROGRESS: at sentence #150000, processed 750000 words, keeping 99 word types
# INFO : collected 99 word types from a corpus of 795200 raw words and 159040 sentences
# INFO : Loading a fresh vocabulary
# INFO : min_count=2 retains 96 unique words (96% of original 99, drops 3)
# INFO : min_count=2 leaves 795197 word corpus (99% of original 795200, drops 3)
# INFO : deleting the raw counts dictionary of 99 items
# INFO : sample=0.001 downsamples 33 most-common words
# INFO : downsampling leaves estimated 159721 word corpus (20.1% of prior 795197)
# INFO : estimated required memory for 96 words and 150 dimensions: 163200 bytes
# INFO : resetting layer weights
# INFO : training model with 4 workers on 96 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 1 : training on 795200 raw words (159881 effective words) took 0.2s, 802214 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 2 : training on 795200 raw words (159772 effective words) took 0.2s, 909902 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 3 : training on 795200 raw words (160029 effective words) took 0.2s, 815730 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 4 : training on 795200 raw words (159259 effective words) took 0.2s, 817009 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 5 : training on 795200 raw words (159561 effective words) took 0.2s, 805062 effective words/s
# INFO : training on a 3976000 raw words (798502 effective words) took 1.0s, 777287 effective words/s

# %%
model.train(all_block_docs, total_examples=len(all_block_docs), epochs=50)
# Out:
# WARNING : Effective 'alpha' higher than previous training cycles
# INFO : training model with 4 workers on 96 vocabulary and 150 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 1 : training on 795200 raw words (158978 effective words) took 0.2s, 769003 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 2 : training on 795200 raw words (159316 effective words) took 0.2s, 823200 effective words/s
# INFO : worker thread finished; awaiting finish of 3 more threads
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH -
# INFO : worker thread finished; awaiting finish of 2 more threads
# INFO : worker thread finished; awaiting finish of 1 more threads
# INFO : worker thread finished; awaiting finish of 0 more threads
# INFO : EPOCH - 50 : training on 795200 raw words (159948 effective words) took 0.2s, 763086 effective words/s
# INFO : training on a 39760000 raw words (7983548 effective words) took 10.1s, 791104 effective words/s
# (7983548, 39760000)

# %%
def find_similar_to(word):
    return [w for w in w2v_model.wv.most_similar(positive=[word])]

# %%
find_similar_to('motion_turnright')
# Out:
# [('motion_changeyby', 0.5849893689155579),
#  ('motion_turnleft', 0.5804131627082825),
#  ('control_if', 0.48881152272224426),
#  ('motion_changexby', 0.4553658664226532),
#  ('motion_goto', 0.35792821645736694),
#  ('control_if_else', 0.33844611048698425),
#  ('motion_glideto', 0.3328104317188263),
#  ('data_replaceitemoflist', 0.3049737513065338),
#  ('looks_nextcostume', 0.3026292324066162),
#  ('data_changevariableby', 0.3014408051967621)]

# %%
X = model[model.wv.vocab]
# Out:
# /Users/tylerangert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
plt.scatter(result[:, 0], result[:, 1])

words = list(model.wv.vocab)
for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0], result[i, 1]))
    
plt.figure(figsize=(18, 30), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
list(model.wv.vocab.keys())
# Out:
# ['event_whenflagclicked',
#  'data_setvariableto',
#  'looks_hide',
#  'none',
#  'event_whenkeypressed',
#  'motion_pointindirection',
#  'motion_movesteps',
#  'looks_switchcostumeto',
#  'motion_gotoxy',
#  'looks_show',
#  'control_forever',
#  'event_whenbackdropswitchesto',
#  'control_if',
#  'control_repeat_until',
#  'event_whenthisspriteclicked',
#  'sensing_askandwait',
#  'procedures_definition',
#  'looks_sayforsecs',
#  'data_addtolist',
#  'control_wait_until',
#  'data_hidevariable',
#  'data_deletealloflist',
#  'control_wait',
#  'event_whenbroadcastreceived',
#  'looks_nextcostume',
#  'event_broadcast',
#  'looks_gotofrontback',
#  'control_start_as_clone',
#  'control_repeat',
#  'control_delete_this_clone',
#  'sound_play',
#  'looks_seteffectto',
#  'looks_switchbackdropto',
#  'motion_glidesecstoxy',
#  'sound_playuntildone',
#  'looks_setsizeto',
#  'looks_nextbackdrop',
#  'sound_setvolumeto',
#  'looks_changesizeby',
#  'data_changevariableby',
#  'looks_cleargraphiceffects',
#  'pen_clear',
#  'procedures_call',
#  'looks_goforwardbackwardlayers',
#  'data_showvariable',
#  'motion_changexby',
#  'motion_changeyby',
#  'control_if_else',
#  'data_deleteoflist',
#  'control_create_clone_of',
#  'control_stop',
#  'motion_goto',
#  'motion_pointtowards',
#  'motion_setx',
#  'motion_sety',
#  'motion_turnright',
#  'sound_stopallsounds',
#  'pen_setPenSizeTo',
#  'sensing_resettimer',
#  'pen_penDown',
#  'pen_setPenColorToColor',
#  'pen_penUp',
#  'music_setInstrument',
#  'text2speech_setVoice',
#  'text2speech_speakAndWait',
#  'looks_say',
#  'looks_changeeffectby',
#  'videoSensing_whenMotionGreaterThan',
#  'videoSensing_videoToggle',
#  'videoSensing_setVideoTransparency',
#  'motion_setrotationstyle',
#  'event_broadcastandwait',
#  'motion_turnleft',
#  'sensing_setdragmode',
#  'text2speech_setLanguage',
#  'data_replaceitemoflist',
#  'sound_seteffectto',
#  'event_whengreaterthan',
#  'data_hidelist',
#  'data_showlist',
#  'looks_thinkforsecs',
#  'motion_glideto',
#  'data_insertatlist',
#  'music_playNoteForBeats',
#  'sound_changevolumeby',
#  'motion_ifonedgebounce',
#  'pen_stamp',
#  'looks_think',
#  'music_setTempo',
#  'sound_cleareffects',
#  'pen_setPenHueToNumber',
#  'pen_setPenShadeToNumber',
#  'pen_setPenColorParamTo',
#  'ev3_beep',
#  'music_restForBeats',
#  'music_playDrumForBeats']

# %%
result = model.most_similar(positive=['looks_sayforsecs', 'sound_playuntildone'], negative=['looks_say'], topn=1)
# Out:
# /Users/tylerangert/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
result
# Out:
# [('looks_switchbackdropto', 0.4863339066505432)]

# %%
import json
import pprint
import collections
import requests
import pandas as pd
import numpy as np
from pynpm import NPMPackage

# %%
def get_top_blocks(blocks):
    return {bid: block for bid,block in blocks.items() if 'topLevel' in list(block) and block['topLevel']}

# %%
def build_stack_sequence(all_blocks, tid):
    """ builds a sequential stack sequence """
    stack = []
    curr_id = tid
    stack.append(all_blocks[curr_id]['opcode'])
    while curr_id is not None:
        curr_id = all_blocks[curr_id]['next']
        if curr_id != None:
            stack.append(all_blocks[curr_id]['opcode'])
    return stack

# %%
def build_rnn_sequences(stack, seq_len):
    """
    produces a list of rnn-ready sequences given an input stack sequence
    iterates through
    """
    seqs = []
    for i in range(seq_len):
        seq = stack[i:seq_len]
        if(len(seq)<seq_len):
            seq.extend([None] * (seq_len - len(seq)))
        if(not all(el is None for el in seq)):
            seqs.append(seq)
    return seqs

# %%
def get_terminal_blocks(blocks):
    return { k:blocks[k] for k in blocks
             if type(blocks[k]) is dict # prevents stop blocks
             if blocks[k]['next'] is None # nothing after it
             if not blocks[k]['shadow'] # not a shadow block
             if 'operator' not in blocks[k]['opcode'] # not an operator
             if 'SUBSTACK' not in blocks[k]['inputs'] # has no children
             if 'SUBSTACK2' not in blocks[k]['inputs'] }

# %%
def filter_blocks(blocks):
    return { k:blocks[k] for k in blocks 
            if type(blocks[k]) is dict # prevents stop blocks
            if 'operator' not in blocks[k]['opcode'] # prevents operators
           }

# %%
def get_paths(blks):
    """ returns all of the paths from top->terminal block of a sprite """
    paths = []
    blks = filter_blocks(blks)
    
    # symbols for direction in the tree
    _nest = '>'
    _next = '_'
    
    terminals = get_terminal_blocks(blks)

    for t in terminals:

        # initialize the path ending with the terminal

        curr_parent_id = t
        curr_parent = blks[curr_parent_id]
        next_parent_id = terminals[t]['parent']
        path = [curr_parent['opcode']]
        
        should_dump = False
        
        if next_parent_id is not None and next_parent_id in blks:
            
            next_parent = blks[next_parent_id]
            
            if t == next_parent['next']:
                path.insert(0,_next)
            else:
                path.insert(0,_nest)

            # initializie before traverseing
            path.insert(0,next_parent['opcode'])

            # begin the traversal with the next parent
            curr_parent_id = next_parent_id

            # go up the tree
            while True:
                # set the current parent to its own parent

                # in order to determine nesting / sequence,
                # if the current block id is the same as its parent's next
                # then it's next
                #  if it's not, then it's nested
                next_parent_id = blks[curr_parent_id]['parent']
                
                if next_parent_id is not None and next_parent_id in blks:
                    
                        curr_parent = blks[curr_parent_id]
                        next_parent = blks[next_parent_id]

                        if curr_parent_id == next_parent['next']:
                            path.insert(0,_next)
                        else:
                            path.insert(0,_nest)

                        path.insert(0,next_parent['opcode'])

                        # reset for the next iteration
                        curr_parent_id = next_parent_id
    
                else:
                    break
                    
            if not should_dump:
                paths.append(path)
            else:
                continue
    
    return paths

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
project_id_df = pd.read_csv('data/project-ids/project_ids_train_1000.csv')

# %%
project_ids = list(project_id_df['id'])

# %%
def download_projects(project_ids):
    for pid in project_ids:
        proj_url = 'https://projects.scratch.mit.edu/{}'.format(pid)
        r = requests.get(url = proj_url, params = {}) 
        proj_data = r.json()
        with open('data/project-json/{}.json'.format(pid), 'w') as outfile:
            json.dump(proj_data, outfile)

# %%
def make_sequences(sequence_length):
    print('what')
    all_sequences = []

    for pid in project_ids:
        # sending get request and saving the response as response object 
        proj_path = 'data/project-json/{}.json'.format(pid)

        # load the pre-downloaded project json data
        with open(proj_path) as f:

            proj_data = json.load(f)
            sprites = proj_data['targets'][1:] 

            for s in sprites:
                all_blocks = s['blocks']
                paths = get_paths(all_blocks)
                
                # filter out any lone soliders if necessary
                paths = [p for p in paths if len(p) > 1]
                all_sequences.extend(paths)
    return all_sequences

# %%
def old_sequences():
    for pid in project_ids:
        # sending get request and saving the response as response object 
        proj_path = 'data/project-json/{}.json'.format(pid)

        # load the pre-downloaded project json data
        with open(proj_path) as f:

            proj_data = json.load(f)
            sprites = proj_data['targets'][1:] 

            for s in sprites:
                all_blocks = s['blocks']
                tops = get_top_blocks(all_blocks)
                topids = [bid for bid,block in tops.items()]
                for tid in topids:
                    s = build_stack_sequence(all_blocks, tid)
                    #Only build sequences out of stacks with at least two blocks
                    if(len(s) > 1):
                        seqs = build_rnn_sequences(s,sequence_length)
                        all_sequences.extend(seqs)

# %%
import numpy as np

# %%
def reject_outliers(data, m=2):
    return data[abs(np.array(data) - np.mean(data)) < m * np.std(data)]

# %%
all_seqs = make_sequences(5)
# Out:
# what

# %%
lengths = [len(sub) for sub in all_seqs]
mean = np.mean(lengths)
std = np.std(lengths)

# %%
mean
# Out:
# 17.37940212275634

# %%
std
# Out:
# 17.506860211198592

# %%
# filtered_seqs = [seq for seq in s if abs(len(seq) - np.mean(lengths)) < 2 * np.std(lengths)]
std_dev = 1
filtered_seqs = list(filter(lambda s: abs(len(s) - mean) < std_dev * std, all_seqs))

# %%
## make the relevant sequences

# %%
sequence_df = pd.DataFrame(filtered_seqs)

# %%
sequence_df
# Out:
#                                   0  1                        2     3   \
# 0              event_whenflagclicked  _       data_setvariableto     _
# 1               event_whenkeypressed  _  motion_pointindirection     _
# 2               event_whenkeypressed  _         motion_movesteps     _
# 3               event_whenkeypressed  _    looks_switchcostumeto     _
# 4              event_whenflagclicked  _          control_forever     >
# 5              event_whenflagclicked  _          control_forever     >
# 6              event_whenflagclicked  _          control_forever     >
# 7              event_whenflagclicked  _          control_forever     >
# 8              event_whenflagclicked  _          control_forever     >
# 9              event_whenflagclicked  _          control_forever     >
# 10             event_whenflagclicked  _          control_forever     >
# 11             event_whenflagclicked  _          control_forever     >
# 12             event_whenflagclicked  _          control_forever     >
# 13             event_whenflagclicked  _          control_forever     >
# 14             event_whenflagclicked  _          control_forever     >
# 15             event_whenflagclicked  _          control_forever     >
# 16             event_whenflagclicked  _          control_forever     >
# 17             event_whenflagclicked  _          control_forever     >
# 18              event_whenkeypressed  _         motion_movesteps     _
# 19              event_whenkeypressed  _         motion_movesteps     _
# 20      event_whenbackdropswitchesto  _          control_forever     >
# 21      event_whenbackdropswitchesto  _          control_forever     >
# 22      event_whenbackdropswitchesto  _          control_forever     >
# 23      event_whenbackdropswitchesto  _          control_forever     >
# 24             event_whenflagclicked  _          control_forever     >
# 25             event_whenflagclicked  _          control_forever     >
# 26      event_whenbackdropswitchesto  _          control_forever     >
# 27      event_whenbackdropswitchesto  _          control_forever     >
# 28      event_whenbackdropswitchesto  _               looks_hide  None
# 29      event_whenbackdropswitchesto  _               looks_hide  None
# ...                              ... ..                      ...   ...
# 107835   event_whenbroadcastreceived  _                pen_penUp     _
# 107836   event_whenbroadcastreceived  _                pen_penUp     _
# 107837   event_whenbroadcastreceived  _                pen_penUp     _
# 107838         event_whenflagclicked  _               looks_hide     _
# 107839          event_whenkeypressed  _                pen_clear  None
# 107840         event_whenflagclicked  _          control_forever     >
# 107841         event_whenflagclicked  _          control_forever     >
# 107842   event_whenbroadcastreceived  _               looks_show     _
# 107843   event_whenbroadcastreceived  _               looks_show     _
# 107844   event_whenbroadcastreceived  _               looks_show     _
# 107845   event_whenbroadcastreceived  _               looks_show     _
# 107846   event_whenbroadcastreceived  _               looks_show     _
# 107847   event_whenbroadcastreceived  _               looks_show     _
# 107848          event_whenkeypressed  _                pen_clear  None
# 107849   event_whenbroadcastreceived  _               looks_show     _
# 107850   event_whenbroadcastreceived  _               looks_show     _
# 107851   event_whenbroadcastreceived  _               looks_show     _
# 107852   event_whenbroadcastreceived  _               looks_show     _
# 107853   event_whenbroadcastreceived  _               looks_show     _
# 107854   event_whenbroadcastreceived  _               looks_show     _
# 107855         event_whenflagclicked  _               looks_hide  None
# 107856   event_whenbroadcastreceived  _          control_forever     >
# 107857         event_whenflagclicked  _          control_forever     >
# 107858         event_whenflagclicked  _          control_forever     >
# 107859         event_whenflagclicked  _            motion_gotoxy  None
# 107860         event_whenflagclicked  _            motion_gotoxy  None
# 107861         event_whenflagclicked  _            motion_gotoxy  None
# 107862   event_whenbroadcastreceived  _     control_repeat_until     >
# 107863   event_whenbroadcastreceived  _     control_repeat_until     >
# 107864   event_whenbroadcastreceived  _     control_repeat_until     >
#
#                              4     5                        6     7   \
# 0                    looks_hide  None                     None  None
# 1              motion_movesteps  None                     None  None
# 2       motion_pointindirection  None                     None  None
# 3                 motion_gotoxy     _               looks_show  None
# 4                    control_if     >   sensing_touchingobject  None
# 5                    control_if     >         looks_sayforsecs     _
# 6                    control_if     >   sensing_touchingobject  None
# 7                    control_if     >         looks_sayforsecs     _
# 8                    control_if     >   sensing_touchingobject  None
# 9                    control_if     >         looks_sayforsecs     _
# 10                   control_if     >   sensing_touchingobject  None
# 11                   control_if     >         looks_sayforsecs     _
# 12                   control_if     >   sensing_touchingobject  None
# 13                   control_if     >         looks_sayforsecs     _
# 14                   control_if     >   sensing_touchingobject  None
# 15                   control_if     >         looks_sayforsecs     _
# 16                   control_if     >   sensing_touchingobject  None
# 17                   control_if     >   looks_switchbackdropto  None
# 18      motion_pointindirection     _    looks_switchcostumeto  None
# 19      motion_pointindirection     _    looks_switchcostumeto  None
# 20                   control_if     >   sensing_touchingobject  None
# 21                   control_if     >   looks_switchbackdropto  None
# 22                   control_if     >   sensing_touchingobject  None
# 23                   control_if     >         looks_sayforsecs     _
# 24                   control_if     >   sensing_touchingobject  None
# 25                   control_if     >   looks_switchbackdropto  None
# 26                   control_if  None                     None  None
# 27                   control_if     >   sensing_touchingobject  None
# 28                         None  None                     None  None
# 29                         None  None                     None  None
# ...                         ...   ...                      ...   ...
# 107835               looks_show     _            motion_gotoxy     _
# 107836               looks_show     _            motion_gotoxy     _
# 107837               looks_show     _            motion_gotoxy     _
# 107838          control_forever     >              motion_goto     _
# 107839                     None  None                     None  None
# 107840    looks_switchcostumeto  None                     None  None
# 107841    looks_switchcostumeto     >               sensing_of  None
# 107842          control_forever     >               control_if     >
# 107843          control_forever     >               control_if     _
# 107844          control_forever     >               control_if     _
# 107845          control_forever     >               control_if     _
# 107846          control_forever     >               control_if     _
# 107847          control_forever     >               control_if     _
# 107848                     None  None                     None  None
# 107849          control_forever     >               control_if     >
# 107850          control_forever     >               control_if     _
# 107851          control_forever     >               control_if     _
# 107852          control_forever     >               control_if     _
# 107853          control_forever     >               control_if     _
# 107854          control_forever     >               control_if     _
# 107855                     None  None                     None  None
# 107856              motion_goto     _          looks_setsizeto  None
# 107857    looks_switchcostumeto  None                     None  None
# 107858    looks_switchcostumeto     >               sensing_of  None
# 107859                     None  None                     None  None
# 107860                     None  None                     None  None
# 107861                     None  None                     None  None
# 107862               control_if     >  motion_setrotationstyle     _
# 107863               control_if     >  motion_setrotationstyle     _
# 107864               control_if     _               control_if     >
#
#                             8     9         ...           23          24  \
# 0                         None  None        ...         None        None
# 1                         None  None        ...         None        None
# 2                         None  None        ...         None        None
# 3                         None  None        ...         None        None
# 4                         None  None        ...         None        None
# 5        data_changevariableby     _        ...         None        None
# 6                         None  None        ...         None        None
# 7        data_changevariableby     _        ...         None        None
# 8                         None  None        ...         None        None
# 9        data_changevariableby     _        ...         None        None
# 10                        None  None        ...         None        None
# 11       data_changevariableby     _        ...         None        None
# 12                        None  None        ...         None        None
# 13       data_changevariableby     _        ...         None        None
# 14                        None  None        ...         None        None
# 15       data_changevariableby  None        ...         None        None
# 16                        None  None        ...         None        None
# 17                        None  None        ...         None        None
# 18                        None  None        ...         None        None
# 19                        None  None        ...         None        None
# 20                        None  None        ...         None        None
# 21                        None  None        ...         None        None
# 22                        None  None        ...         None        None
# 23      looks_switchbackdropto  None        ...         None        None
# 24                        None  None        ...         None        None
# 25                        None  None        ...         None        None
# 26                        None  None        ...         None        None
# 27                        None  None        ...         None        None
# 28                        None  None        ...         None        None
# 29                        None  None        ...         None        None
# ...                        ...   ...        ...          ...         ...
# 107835      data_setvariableto     _        ...            _  control_if
# 107836      data_setvariableto     _        ...            _  control_if
# 107837      data_setvariableto     _        ...            _  control_if
# 107838         looks_setsizeto  None        ...         None        None
# 107839                    None  None        ...         None        None
# 107840                    None  None        ...         None        None
# 107841                    None  None        ...         None        None
# 107842         motion_turnleft  None        ...         None        None
# 107843              control_if     >        ...         None        None
# 107844              control_if     _        ...         None        None
# 107845              control_if     _        ...         None        None
# 107846              control_if     _        ...         None        None
# 107847              control_if     _        ...         None        None
# 107848                    None  None        ...         None        None
# 107849         motion_turnleft  None        ...         None        None
# 107850              control_if     >        ...         None        None
# 107851              control_if     _        ...         None        None
# 107852              control_if     _        ...         None        None
# 107853              control_if     _        ...         None        None
# 107854              control_if     _        ...         None        None
# 107855                    None  None        ...         None        None
# 107856                    None  None        ...         None        None
# 107857                    None  None        ...         None        None
# 107858                    None  None        ...         None        None
# 107859                    None  None        ...         None        None
# 107860                    None  None        ...         None        None
# 107861                    None  None        ...         None        None
# 107862         control_forever     >        ...         None        None
# 107863         control_forever     >        ...         None        None
# 107864              looks_hide  None        ...         None        None
#
#           25          26    27                     28    29  \
# 0       None        None  None                   None  None
# 1       None        None  None                   None  None
# 2       None        None  None                   None  None
# 3       None        None  None                   None  None
# 4       None        None  None                   None  None
# 5       None        None  None                   None  None
# 6       None        None  None                   None  None
# 7       None        None  None                   None  None
# 8       None        None  None                   None  None
# 9       None        None  None                   None  None
# 10      None        None  None                   None  None
# 11      None        None  None                   None  None
# 12      None        None  None                   None  None
# 13      None        None  None                   None  None
